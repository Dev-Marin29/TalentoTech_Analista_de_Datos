# %%
# ==========================================
# PROYECTO FINAL - ANALISTA DE DATOS
# PRESUNTOS SUICIDIOS EN COLOMBIA (2020–2025)
# ==========================================

import pandas as pd  # 📦 Importamos Pandas

# 1️⃣ Cargar el archivo CSV completo
df_presuntos = pd.read_csv(  # Leemos el archivo CSV
    r"E:\TalentoTech_Analista_de_Datos\Ds_a_Importar\Presuntos_Suicidios._Colombia,_2015_a_2024._Cifras_definitivas_20251003.csv"
)

# 2️⃣ Filtrar solo los años desde 2020 hasta 2025
df_presuntos = df_presuntos[df_presuntos["Año del hecho"] >= 2020]  # Filtramos los años 2020 en adelante

# 3️⃣ Reiniciar el ID para que empiece desde 1
df_presuntos["ID"] = range(1, len(df_presuntos) + 1)  # Reasignamos la columna ID con valores 1...n

# 4️⃣ Establecer la columna ID como índice
df_presuntos.set_index("ID", inplace=True)  # Usamos la columna ID como índice del DataFrame

# 5️⃣ Verificar resultado
print("Cantidad de filas y columnas:", df_presuntos.shape)  # Muestra dimensiones del DataFrame
print("Años incluidos en el DataFrame:")  # Mensaje informativo
print(df_presuntos["Año del hecho"].unique())  # Confirma los años filtrados

# 6️⃣ Mostrar las primeras filas
df_presuntos.head()  # Visualiza las primeras 5 filas
# Out:
# Cantidad de filas y columnas: (14270, 31)
# Años incluidos en el DataFrame:
# [2020 2021 2022 2023 2024]
#     Año del hecho Grupo de Edad Quinquenal       Grupo Mayor Menor de Edad  \
# ID
# 1            2020                 (30 a 34)  b) Mayores de Edad (>18 años)
# 2            2020                 (18 a 19)  b) Mayores de Edad (>18 años)
# 3            2020                 (20 a 24)  b) Mayores de Edad (>18 años)
# 4            2020                 (25 a 29)  b) Mayores de Edad (>18 años)
# 5            2020                 (18 a 19)  b) Mayores de Edad (>18 años)
#
#    Grupo de Edad judicial         Ciclo Vital Sexo de la victima  \
# ID
# 1               (29 a 34)   (29 a 59) Adultez              Mujer
# 2               (18 a 19)  (18 a 28) Juventud             Hombre
# 3               (20 a 24)  (18 a 28) Juventud             Hombre
# 4               (25 a 28)  (18 a 28) Juventud             Hombre
# 5               (18 a 19)  (18 a 28) Juventud             Hombre
#
#                   Estado Civil País de Nacimiento  \
# ID
# 1                  Unión libre           Colombia
# 2                   Soltero(a)           Colombia
# 3                   Soltero(a)           Colombia
# 4   Separado(a), divorciado(a)           Colombia
# 5                   Soltero(a)           Colombia
#
#                                     Escolaridad Pertenencia Grupal  ...  \
# ID                                                                  ...
# 1             Educación media o secundaria alta            Ninguno  ...
# 2   Educación técnica profesional y tecnológica            Ninguno  ...
# 3                     Educación básica primaria            Ninguno  ...
# 4                               Sin información            Ninguno  ...
# 5             Educación media o secundaria alta            Ninguno  ...
#
#    Manera de Muerte Mecanismo Causal de la Lesión Fatal  \
# ID
# 1       2 Suicidios              Generadores de asfixia
# 2       2 Suicidios                              Tóxico
# 3       2 Suicidios              Generadores de asfixia
# 4       2 Suicidios              Generadores de asfixia
# 5       2 Suicidios                              Tóxico
#
#    Diagnostico Topográfico de la Lesión Fatal  \
# ID
# 1                            Trauma de cuello
# 2                                Sin lesiones
# 3                            Trauma de cuello
# 4                            Trauma de cuello
# 5                                Sin lesiones
#
#                   Razón del Suicidio  Localidad del Hecho Ancestro Racial  \
# ID
# 1   Conflicto con pareja o ex-pareja                 Suba         Mestizo
# 2         Enfermedad física o mental        San Cristobal         Mestizo
# 3         Enfermedad física o mental       Ciudad Bolivar         Mestizo
# 4   Conflicto con pareja o ex-pareja                 Suba         Mestizo
# 5         Enfermedad física o mental             Fontibon         Mestizo
#
#    Pueblo Indígena          Orientación Sexual         Identidad de Género  \
# ID
# 1        No aplica  No había sido implementada  No había sido implementada
# 2        No aplica  No había sido implementada  No había sido implementada
# 3        No aplica  No había sido implementada  No había sido implementada
# 4        No aplica  No había sido implementada  No había sido implementada
# 5        No aplica  No había sido implementada  No había sido implementada
#
#                    Transgénero
# ID
# 1   No había sido implementada
# 2   No había sido implementada
# 3   No había sido implementada
# 4   No había sido implementada
# 5   No había sido implementada
#
# [5 rows x 31 columns]

# %%
df_presuntos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14270 entries, 1 to 14270
# Data columns (total 31 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Año del hecho                               14270 non-null  int64
#  1   Grupo de Edad Quinquenal                    14270 non-null  object
#  2   Grupo Mayor Menor de Edad                   14270 non-null  object
#  3   Grupo de Edad judicial                      14270 non-null  object
#  4   Ciclo Vital                                 14270 non-null  object
#  5   Sexo de la victima                          14270 non-null  object
#  6   Estado Civil                                14270 non-null  object
#  7   País de Nacimiento                          14270 non-null  object
#  8   Escolaridad                                 14270 non-null  object
#  9   Pertenencia Grupal                          14270 non-null  object
#  10  Pertenencia Étnica                          14270 non-null  object
#  11  Mes del hecho                               14270 non-null  object
#  12  Dia del hecho                               14270 non-null  object
#  13  Rango de Hora del Hecho X 3 Horas           14270 non-null  object
#  14  Código Dane Municipio                       14270 non-null  int64
#  15  Municipio del hecho DANE                    14270 non-null  object
#  16  Departamento del hecho DANE                 14270 non-null  object
#  17  Código Dane Departamento                    14270 non-null  int64
#  18  Escenario del Hecho                         14270 non-null  object
#  19  Zona del Hecho                              14270 non-null  object
#  20  Circunstancia del Hecho Detallada           14270 non-null  object
#  21  Manera de Muerte                            14270 non-null  object
#  22  Mecanismo Causal de la Lesión Fatal         14270 non-null  object
#  23  Diagnostico Topográfico de la Lesión Fatal  14270 non-null  object
#  24  Razón del Suicidio                          14270 non-null  object
#  25  Localidad del Hecho                         14270 non-null  object
#  26  Ancestro Racial                             14270 non-null  object
#  27  Pueblo Indígena                             14270 non-null  object
#  28  Orientación Sexual                          14270 non-null  object
#  29  Identidad de Género                         14270 non-null  object
#  30  Transgénero                                 14270 non-null  object
# dtypes: int64(3), object(28)
# memory usage: 3.5+ MB

# %%
# Nombres de las columnas
print(df_presuntos.columns.tolist())

# Ver las primeras 10 filas
df_presuntos.head(10)
# Out:
# ['Año del hecho', 'Grupo de Edad Quinquenal ', 'Grupo Mayor Menor de Edad', 'Grupo de Edad judicial', 'Ciclo Vital', 'Sexo de la victima', 'Estado Civil', 'País de Nacimiento', 'Escolaridad', 'Pertenencia Grupal', 'Pertenencia Étnica', 'Mes del hecho', 'Dia del hecho', 'Rango de Hora del Hecho X 3 Horas', 'Código Dane Municipio', 'Municipio del hecho DANE', 'Departamento del hecho DANE', 'Código Dane Departamento', 'Escenario del Hecho', 'Zona del Hecho', 'Circunstancia del Hecho Detallada', 'Manera de Muerte', 'Mecanismo Causal de la Lesión Fatal', 'Diagnostico Topográfico de la Lesión Fatal', 'Razón del Suicidio', 'Localidad del Hecho', 'Ancestro Racial', 'Pueblo Indígena', 'Orientación Sexual', 'Identidad de Género', 'Transgénero']
#     Año del hecho Grupo de Edad Quinquenal       Grupo Mayor Menor de Edad  \
# ID
# 1            2020                 (30 a 34)  b) Mayores de Edad (>18 años)
# 2            2020                 (18 a 19)  b) Mayores de Edad (>18 años)
# 3            2020                 (20 a 24)  b) Mayores de Edad (>18 años)
# 4            2020                 (25 a 29)  b) Mayores de Edad (>18 años)
# 5            2020                 (18 a 19)  b) Mayores de Edad (>18 años)
# 6            2020                 (55 a 59)  b) Mayores de Edad (>18 años)
# 7            2020                 (30 a 34)  b) Mayores de Edad (>18 años)
# 8            2020                 (15 a 17)  a) Menores de Edad (<18 años)
# 9            2020                 (35 a 39)  b) Mayores de Edad (>18 años)
# 10           2020                 (70 a 74)  b) Mayores de Edad (>18 años)
#
#    Grupo de Edad judicial               Ciclo Vital Sexo de la victima  \
# ID
# 1               (29 a 34)         (29 a 59) Adultez              Mujer
# 2               (18 a 19)        (18 a 28) Juventud             Hombre
# 3               (20 a 24)        (18 a 28) Juventud             Hombre
# 4               (25 a 28)        (18 a 28) Juventud             Hombre
# 5               (18 a 19)        (18 a 28) Juventud             Hombre
# 6               (55 a 59)         (29 a 59) Adultez             Hombre
# 7               (29 a 34)         (29 a 59) Adultez             Hombre
# 8               (14 a 17)    (12 a 17) Adolescencia              Mujer
# 9               (35 a 39)         (29 a 59) Adultez             Hombre
# 10              (70 a 74)  (Más de 60) Adulto Mayor             Hombre
#
#                   Estado Civil País de Nacimiento  \
# ID
# 1                  Unión libre           Colombia
# 2                   Soltero(a)           Colombia
# 3                   Soltero(a)           Colombia
# 4   Separado(a), divorciado(a)           Colombia
# 5                   Soltero(a)           Colombia
# 6                   Soltero(a)           Colombia
# 7                   Soltero(a)           Colombia
# 8                   Soltero(a)           Colombia
# 9                  Unión libre           Colombia
# 10                  Soltero(a)           Colombia
#
#                                     Escolaridad Pertenencia Grupal  ...  \
# ID                                                                  ...
# 1             Educación media o secundaria alta            Ninguno  ...
# 2   Educación técnica profesional y tecnológica            Ninguno  ...
# 3                     Educación básica primaria            Ninguno  ...
# 4                               Sin información            Ninguno  ...
# 5             Educación media o secundaria alta            Ninguno  ...
# 6                     Educación básica primaria            Ninguno  ...
# 7             Educación media o secundaria alta    Sin información  ...
# 8             Educación media o secundaria alta               Otro  ...
# 9             Educación media o secundaria alta               Otro  ...
# 10                    Educación básica primaria            Ninguno  ...
#
#    Manera de Muerte Mecanismo Causal de la Lesión Fatal  \
# ID
# 1       2 Suicidios              Generadores de asfixia
# 2       2 Suicidios                              Tóxico
# 3       2 Suicidios              Generadores de asfixia
# 4       2 Suicidios              Generadores de asfixia
# 5       2 Suicidios                              Tóxico
# 6       2 Suicidios              Generadores de asfixia
# 7       2 Suicidios          Proyectil de arma de fuego
# 8       2 Suicidios                              Tóxico
# 9       2 Suicidios              Generadores de asfixia
# 10      2 Suicidios              Generadores de asfixia
#
#    Diagnostico Topográfico de la Lesión Fatal  \
# ID
# 1                            Trauma de cuello
# 2                                Sin lesiones
# 3                            Trauma de cuello
# 4                            Trauma de cuello
# 5                                Sin lesiones
# 6                            Trauma de cuello
# 7                             Trauma de Tórax
# 8                                Sin lesiones
# 9                            Trauma de cuello
# 10                             Por determinar
#
#                   Razón del Suicidio  Localidad del Hecho  Ancestro Racial  \
# ID
# 1   Conflicto con pareja o ex-pareja                 Suba          Mestizo
# 2         Enfermedad física o mental        San Cristobal          Mestizo
# 3         Enfermedad física o mental       Ciudad Bolivar          Mestizo
# 4   Conflicto con pareja o ex-pareja                 Suba          Mestizo
# 5         Enfermedad física o mental             Fontibon          Mestizo
# 6                    Sin información        San Cristobal          Mestizo
# 7   Conflicto con pareja o ex-pareja                 Bosa          Mestizo
# 8         Enfermedad física o mental              Usaquen          Mestizo
# 9   Conflicto con pareja o ex-pareja                 Bosa          Mestizo
# 10        Enfermedad física o mental                 Bosa  Sin Información
#
#    Pueblo Indígena          Orientación Sexual         Identidad de Género  \
# ID
# 1        No aplica  No había sido implementada  No había sido implementada
# 2        No aplica  No había sido implementada  No había sido implementada
# 3        No aplica  No había sido implementada  No había sido implementada
# 4        No aplica  No había sido implementada  No había sido implementada
# 5        No aplica  No había sido implementada  No había sido implementada
# 6        No aplica  No había sido implementada  No había sido implementada
# 7        No aplica  No había sido implementada  No había sido implementada
# 8        No aplica  No había sido implementada  No había sido implementada
# 9        No aplica  No había sido implementada  No había sido implementada
# 10       No aplica  No había sido implementada  No había sido implementada
#
#                    Transgénero
# ID
# 1   No había sido implementada
# 2   No había sido implementada
# 3   No había sido implementada
# 4   No había sido implementada
# 5   No había sido implementada
# 6   No había sido implementada
# 7   No había sido implementada
# 8   No había sido implementada
# 9   No había sido implementada
# 10  No había sido implementada
#
# [10 rows x 31 columns]

# %%
df_presuntos.columns  #Muestra los nombres de Columna
# Out:
# Index(['Año del hecho', 'Grupo de Edad Quinquenal ',
#        'Grupo Mayor Menor de Edad', 'Grupo de Edad judicial', 'Ciclo Vital',
#        'Sexo de la victima', 'Estado Civil', 'País de Nacimiento',
#        'Escolaridad', 'Pertenencia Grupal', 'Pertenencia Étnica',
#        'Mes del hecho', 'Dia del hecho', 'Rango de Hora del Hecho X 3 Horas',
#        'Código Dane Municipio', 'Municipio del hecho DANE',
#        'Departamento del hecho DANE', 'Código Dane Departamento',
#        'Escenario del Hecho', 'Zona del Hecho',
#        'Circunstancia del Hecho Detallada', 'Manera de Muerte',
#        'Mecanismo Causal de la Lesión Fatal',
#        'Diagnostico Topográfico de la Lesión Fatal', 'Razón del Suicidio',
#        'Localidad del Hecho', 'Ancestro Racial', 'Pueblo Indígena',
#        'Orientación Sexual', 'Identidad de Género', 'Transgénero'],
#       dtype='object')

# %%
# Conteo de valores nulos
df_presuntos.isnull().sum()
# Out:
# Año del hecho                                 0
# Grupo de Edad Quinquenal                      0
# Grupo Mayor Menor de Edad                     0
# Grupo de Edad judicial                        0
# Ciclo Vital                                   0
# Sexo de la victima                            0
# Estado Civil                                  0
# País de Nacimiento                            0
# Escolaridad                                   0
# Pertenencia Grupal                            0
# Pertenencia Étnica                            0
# Mes del hecho                                 0
# Dia del hecho                                 0
# Rango de Hora del Hecho X 3 Horas             0
# Código Dane Municipio                         0
# Municipio del hecho DANE                      0
# Departamento del hecho DANE                   0
# Código Dane Departamento                      0
# Escenario del Hecho                           0
# Zona del Hecho                                0
# Circunstancia del Hecho Detallada             0
# Manera de Muerte                              0
# Mecanismo Causal de la Lesión Fatal           0
# Diagnostico Topográfico de la Lesión Fatal    0
# Razón del Suicidio                            0
# Localidad del Hecho                           0
# Ancestro Racial                               0
# Pueblo Indígena                               0
# Orientación Sexual                            0
# Identidad de Género                           0
# Transgénero                                   0
# dtype: int64

# %%
df_presuntos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14270 entries, 1 to 14270
# Data columns (total 31 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Año del hecho                               14270 non-null  int64
#  1   Grupo de Edad Quinquenal                    14270 non-null  object
#  2   Grupo Mayor Menor de Edad                   14270 non-null  object
#  3   Grupo de Edad judicial                      14270 non-null  object
#  4   Ciclo Vital                                 14270 non-null  object
#  5   Sexo de la victima                          14270 non-null  object
#  6   Estado Civil                                14270 non-null  object
#  7   País de Nacimiento                          14270 non-null  object
#  8   Escolaridad                                 14270 non-null  object
#  9   Pertenencia Grupal                          14270 non-null  object
#  10  Pertenencia Étnica                          14270 non-null  object
#  11  Mes del hecho                               14270 non-null  object
#  12  Dia del hecho                               14270 non-null  object
#  13  Rango de Hora del Hecho X 3 Horas           14270 non-null  object
#  14  Código Dane Municipio                       14270 non-null  int64
#  15  Municipio del hecho DANE                    14270 non-null  object
#  16  Departamento del hecho DANE                 14270 non-null  object
#  17  Código Dane Departamento                    14270 non-null  int64
#  18  Escenario del Hecho                         14270 non-null  object
#  19  Zona del Hecho                              14270 non-null  object
#  20  Circunstancia del Hecho Detallada           14270 non-null  object
#  21  Manera de Muerte                            14270 non-null  object
#  22  Mecanismo Causal de la Lesión Fatal         14270 non-null  object
#  23  Diagnostico Topográfico de la Lesión Fatal  14270 non-null  object
#  24  Razón del Suicidio                          14270 non-null  object
#  25  Localidad del Hecho                         14270 non-null  object
#  26  Ancestro Racial                             14270 non-null  object
#  27  Pueblo Indígena                             14270 non-null  object
#  28  Orientación Sexual                          14270 non-null  object
#  29  Identidad de Género                         14270 non-null  object
#  30  Transgénero                                 14270 non-null  object
# dtypes: int64(3), object(28)
# memory usage: 3.5+ MB

# %%
# Conteo de valores nulos y su porcentaje
faltantes = df_presuntos.isnull().sum().sort_values(ascending=False)
porcentaje = (faltantes / len(df_presuntos) * 100).round(2)

# Unir en una sola tabla ordenada
faltantes_df = pd.DataFrame({'Valores Nulos': faltantes, '% del Total': porcentaje})
print(faltantes_df)
# Out:
#                                             Valores Nulos  % del Total
# Año del hecho                                           0          0.0
# Grupo de Edad Quinquenal                                0          0.0
# Grupo Mayor Menor de Edad                               0          0.0
# Grupo de Edad judicial                                  0          0.0
# Ciclo Vital                                             0          0.0
# Sexo de la victima                                      0          0.0
# Estado Civil                                            0          0.0
# País de Nacimiento                                      0          0.0
# Escolaridad                                             0          0.0
# Pertenencia Grupal                                      0          0.0
# Pertenencia Étnica                                      0          0.0
# Mes del hecho                                           0          0.0
# Dia del hecho                                           0          0.0
# Rango de Hora del Hecho X 3 Horas                       0          0.0
# Código Dane Municipio                                   0          0.0
# Municipio del hecho DANE                                0          0.0
# Departamento del hecho DANE                             0          0.0
# Código Dane Departamento                                0          0.0
# Escenario del Hecho                                     0          0.0
# Zona del Hecho                                          0          0.0
# Circunstancia del Hecho Detallada                       0          0.0
# Manera de Muerte                                        0          0.0
# Mecanismo Causal de la Lesión Fatal                     0          0.0
# Diagnostico Topográfico de la Lesión Fatal              0          0.0
# Razón del Suicidio                                      0          0.0
# Localidad del Hecho                                     0          0.0
# Ancestro Racial                                         0          0.0
# Pueblo Indígena                                         0          0.0
# Orientación Sexual                                      0          0.0
# Identidad de Género                                     0          0.0
# Transgénero                                             0          0.0

# %%
# Verificar cuántas veces aparece "Sin información" en todo el DataFrame
conteo_sin_info = (df_presuntos == "Sin información").sum().sum()
print("Total de celdas con 'Sin información':", conteo_sin_info)

sin_info_por_columna = (df_presuntos == "Sin información").sum()
sin_info_por_columna = sin_info_por_columna[sin_info_por_columna > 0]
print(sin_info_por_columna)
# Out:
# Total de celdas con 'Sin información': 37180
# Estado Civil                          1401
# País de Nacimiento                      13
# Escolaridad                           1886
# Pertenencia Grupal                    1626
# Pertenencia Étnica                    1263
# Rango de Hora del Hecho X 3 Horas    10726
# Municipio del hecho DANE                 3
# Departamento del hecho DANE              3
# Escenario del Hecho                    317
# Zona del Hecho                          93
# Razón del Suicidio                    7455
# Localidad del Hecho                  12394
# dtype: int64

# %%
import numpy as np

df_presuntos.replace("Sin información", np.nan, inplace=True)

df_presuntos.isna().sum().sort_values(ascending=False).head(12)
# Out:
# Localidad del Hecho                  12394
# Rango de Hora del Hecho X 3 Horas    10726
# Razón del Suicidio                    7455
# Escolaridad                           1886
# Pertenencia Grupal                    1626
# Estado Civil                          1401
# Pertenencia Étnica                    1263
# Escenario del Hecho                    317
# Zona del Hecho                          93
# País de Nacimiento                      13
# Departamento del hecho DANE              3
# Municipio del hecho DANE                 3
# dtype: int64

# %%
# Calcular cantidad y porcentaje de nulos
faltantes = df_presuntos.isna().sum()
porcentaje = (faltantes / len(df_presuntos) * 100).round(2)

# Unir en una sola tabla
faltantes_df = pd.DataFrame({
    'Valores Nulos': faltantes,
    '% del Total': porcentaje.astype(str) + '%'
})

# Ordenar de mayor a menor
faltantes_df = faltantes_df.sort_values(by='Valores Nulos', ascending=False)

# Mostrar
print(faltantes_df)

""""| Nivel    | Rango (%) | Ejemplo en tu dataset                                                                                    | Recomendación                                                              |
| -------- | --------- | -------------------------------------------------------------------------------------------------------- | -------------------------------------------------------------------------- |
| 🔴 Alto  | +60 %     | `Localidad del Hecho` (86.8%), `Rango de Hora del Hecho X 3 Horas` (75.1%), `Razón del Suicidio` (52.2%) | **Eliminar o mantener solo para referencia**; están demasiado incompletas. |
| 🟡 Medio | 8–20 %    | `Escolaridad`, `Pertenencia Grupal`, `Pertenencia Étnica`, `Estado Civil`                                | **Mantener**, pero tener presente que no están completas.                  |
| 🟢 Bajo  | <5 %      | `Escenario del Hecho`, `Zona del Hecho`, `País de Nacimiento`, etc.                                      | **Mantener sin problema**.                                                 |
| 🟢 Cero  | 0 %       | `Año del hecho`, `Sexo de la víctima`, `Departamento del hecho DANE`, etc.                               | **Completas y confiables**.                                                |
"""
# Out:
#                                             Valores Nulos % del Total
# Localidad del Hecho                                 12394      86.85%
# Rango de Hora del Hecho X 3 Horas                   10726      75.16%
# Razón del Suicidio                                   7455      52.24%
# Escolaridad                                          1886      13.22%
# Pertenencia Grupal                                   1626      11.39%
# Estado Civil                                         1401       9.82%
# Pertenencia Étnica                                   1263       8.85%
# Escenario del Hecho                                   317       2.22%
# Zona del Hecho                                         93       0.65%
# País de Nacimiento                                     13       0.09%
# Departamento del hecho DANE                             3       0.02%
# Municipio del hecho DANE                                3       0.02%
# Ciclo Vital                                             0        0.0%
# Sexo de la victima                                      0        0.0%
# Grupo de Edad Quinquenal                                0        0.0%
# Código Dane Municipio                                   0        0.0%
# Dia del hecho                                           0        0.0%
# Mes del hecho                                           0        0.0%
# Año del hecho                                           0        0.0%
# Grupo Mayor Menor de Edad                               0        0.0%
# Grupo de Edad judicial                                  0        0.0%
# Código Dane Departamento                                0        0.0%
# Circunstancia del Hecho Detallada                       0        0.0%
# Mecanismo Causal de la Lesión Fatal                     0        0.0%
# Manera de Muerte                                        0        0.0%
# Diagnostico Topográfico de la Lesión Fatal              0        0.0%
# Ancestro Racial                                         0        0.0%
# Pueblo Indígena                                         0        0.0%
# Orientación Sexual                                      0        0.0%
# Identidad de Género                                     0        0.0%
# Transgénero                                             0        0.0%
# '"| Nivel    | Rango (%) | Ejemplo en tu dataset                                                                                    | Recomendación                                                              |\n| -------- | --------- | -------------------------------------------------------------------------------------------------------- | -------------------------------------------------------------------------- |\n| 🔴 Alto  | +60 %     | `Localidad del Hecho` (86.8%), `Rango de Hora del Hecho X 3 Horas` (75.1%), `Razón del Suicidio` (52.2%) | **Eliminar o mantener solo para referencia**; están demasiado incompletas. |\n| 🟡 Medio | 8–20 %    | `Escolaridad`, `Pertenencia Grupal`, `Pertenencia Étnica`, `Estado Civil`                                | **Mantener**, pero tener presente que no están completas.                  |\n| 🟢 Bajo  | <5 %      | `Escenario del Hecho`, `Zona del Hecho`, `País de Nacimiento`, etc.                                      | **Mantener sin problema**.                                                 |\n| 🟢 Cero  | 0 %       | `Año del hecho`, `Sexo de la víctima`, `Departamento del hecho DANE`, etc.                               | **Completas y confiables**.                                                |\n'

# %%
df_presuntos=df_presuntos.drop("Localidad del Hecho", axis=1)

# %%
df_presuntos= df_presuntos.drop("Rango de Hora del Hecho X 3 Horas", axis=1)

# %%
df_presuntos=df_presuntos.drop("Grupo de Edad Quinquenal ", axis=1)
df_presuntos=df_presuntos.drop("Grupo Mayor Menor de Edad", axis=1)
df_presuntos=df_presuntos.drop("Grupo de Edad judicial", axis=1)

# %%
df_presuntos = df_presuntos[df_presuntos["País de Nacimiento"].str.strip().str.lower() == "colombia"]

# %%
df_presuntos.info()

df_presuntos.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13819 entries, 1 to 14270
# Data columns (total 26 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Año del hecho                               13819 non-null  int64
#  1   Ciclo Vital                                 13819 non-null  object
#  2   Sexo de la victima                          13819 non-null  object
#  3   Estado Civil                                12481 non-null  object
#  4   País de Nacimiento                          13819 non-null  object
#  5   Escolaridad                                 12021 non-null  object
#  6   Pertenencia Grupal                          12281 non-null  object
#  7   Pertenencia Étnica                          12623 non-null  object
#  8   Mes del hecho                               13819 non-null  object
#  9   Dia del hecho                               13819 non-null  object
#  10  Código Dane Municipio                       13819 non-null  int64
#  11  Municipio del hecho DANE                    13816 non-null  object
#  12  Departamento del hecho DANE                 13816 non-null  object
#  13  Código Dane Departamento                    13819 non-null  int64
#  14  Escenario del Hecho                         13517 non-null  object
#  15  Zona del Hecho                              13732 non-null  object
#  16  Circunstancia del Hecho Detallada           13819 non-null  object
#  17  Manera de Muerte                            13819 non-null  object
#  18  Mecanismo Causal de la Lesión Fatal         13819 non-null  object
#  19  Diagnostico Topográfico de la Lesión Fatal  13819 non-null  object
#  20  Razón del Suicidio                          6596 non-null   object
#  21  Ancestro Racial                             13819 non-null  object
#  22  Pueblo Indígena                             13819 non-null  object
#  23  Orientación Sexual                          13819 non-null  object
#  24  Identidad de Género                         13819 non-null  object
#  25  Transgénero                                 13819 non-null  object
# dtypes: int64(3), object(23)
# memory usage: 2.8+ MB
#     Año del hecho               Ciclo Vital Sexo de la victima  \
# ID
# 1            2020         (29 a 59) Adultez              Mujer
# 2            2020        (18 a 28) Juventud             Hombre
# 3            2020        (18 a 28) Juventud             Hombre
# 4            2020        (18 a 28) Juventud             Hombre
# 5            2020        (18 a 28) Juventud             Hombre
# 6            2020         (29 a 59) Adultez             Hombre
# 7            2020         (29 a 59) Adultez             Hombre
# 8            2020    (12 a 17) Adolescencia              Mujer
# 9            2020         (29 a 59) Adultez             Hombre
# 10           2020  (Más de 60) Adulto Mayor             Hombre
#
#                   Estado Civil País de Nacimiento  \
# ID
# 1                  Unión libre           Colombia
# 2                   Soltero(a)           Colombia
# 3                   Soltero(a)           Colombia
# 4   Separado(a), divorciado(a)           Colombia
# 5                   Soltero(a)           Colombia
# 6                   Soltero(a)           Colombia
# 7                   Soltero(a)           Colombia
# 8                   Soltero(a)           Colombia
# 9                  Unión libre           Colombia
# 10                  Soltero(a)           Colombia
#
#                                     Escolaridad Pertenencia Grupal  \
# ID
# 1             Educación media o secundaria alta            Ninguno
# 2   Educación técnica profesional y tecnológica            Ninguno
# 3                     Educación básica primaria            Ninguno
# 4                                           NaN            Ninguno
# 5             Educación media o secundaria alta            Ninguno
# 6                     Educación básica primaria            Ninguno
# 7             Educación media o secundaria alta                NaN
# 8             Educación media o secundaria alta               Otro
# 9             Educación media o secundaria alta               Otro
# 10                    Educación básica primaria            Ninguno
#
#         Pertenencia Étnica Mes del hecho Dia del hecho  ...  \
# ID                                                      ...
# 1   Sin Pertenencia Étnica         enero        jueves  ...
# 2   Sin Pertenencia Étnica         enero        jueves  ...
# 3   Sin Pertenencia Étnica         enero       viernes  ...
# 4   Sin Pertenencia Étnica         enero        sábado  ...
# 5   Sin Pertenencia Étnica         enero       viernes  ...
# 6   Sin Pertenencia Étnica         enero        sábado  ...
# 7                      NaN         enero       domingo  ...
# 8   Sin Pertenencia Étnica         enero       domingo  ...
# 9   Sin Pertenencia Étnica         enero         lunes  ...
# 10  Sin Pertenencia Étnica         enero     miércoles  ...
#
#     Circunstancia del Hecho Detallada Manera de Muerte  \
# ID
# 1               Autolesión voluntaria      2 Suicidios
# 2               Autolesión voluntaria      2 Suicidios
# 3               Autolesión voluntaria      2 Suicidios
# 4               Autolesión voluntaria      2 Suicidios
# 5               Autolesión voluntaria      2 Suicidios
# 6               Autolesión voluntaria      2 Suicidios
# 7               Autolesión voluntaria      2 Suicidios
# 8               Autolesión voluntaria      2 Suicidios
# 9               Autolesión voluntaria      2 Suicidios
# 10              Autolesión voluntaria      2 Suicidios
#
#    Mecanismo Causal de la Lesión Fatal  \
# ID
# 1               Generadores de asfixia
# 2                               Tóxico
# 3               Generadores de asfixia
# 4               Generadores de asfixia
# 5                               Tóxico
# 6               Generadores de asfixia
# 7           Proyectil de arma de fuego
# 8                               Tóxico
# 9               Generadores de asfixia
# 10              Generadores de asfixia
#
#     Diagnostico Topográfico de la Lesión Fatal  \
# ID
# 1                             Trauma de cuello
# 2                                 Sin lesiones
# 3                             Trauma de cuello
# 4                             Trauma de cuello
# 5                                 Sin lesiones
# 6                             Trauma de cuello
# 7                              Trauma de Tórax
# 8                                 Sin lesiones
# 9                             Trauma de cuello
# 10                              Por determinar
#
#                   Razón del Suicidio  Ancestro Racial Pueblo Indígena  \
# ID
# 1   Conflicto con pareja o ex-pareja          Mestizo       No aplica
# 2         Enfermedad física o mental          Mestizo       No aplica
# 3         Enfermedad física o mental          Mestizo       No aplica
# 4   Conflicto con pareja o ex-pareja          Mestizo       No aplica
# 5         Enfermedad física o mental          Mestizo       No aplica
# 6                                NaN          Mestizo       No aplica
# 7   Conflicto con pareja o ex-pareja          Mestizo       No aplica
# 8         Enfermedad física o mental          Mestizo       No aplica
# 9   Conflicto con pareja o ex-pareja          Mestizo       No aplica
# 10        Enfermedad física o mental  Sin Información       No aplica
#
#             Orientación Sexual         Identidad de Género  \
# ID
# 1   No había sido implementada  No había sido implementada
# 2   No había sido implementada  No había sido implementada
# 3   No había sido implementada  No había sido implementada
# 4   No había sido implementada  No había sido implementada
# 5   No había sido implementada  No había sido implementada
# 6   No había sido implementada  No había sido implementada
# 7   No había sido implementada  No había sido implementada
# 8   No había sido implementada  No había sido implementada
# 9   No había sido implementada  No había sido implementada
# 10  No había sido implementada  No había sido implementada
#
#                    Transgénero
# ID
# 1   No había sido implementada
# 2   No había sido implementada
# 3   No había sido implementada
# 4   No había sido implementada
# 5   No había sido implementada
# 6   No había sido implementada
# 7   No había sido implementada
# 8   No había sido implementada
# 9   No había sido implementada
# 10  No había sido implementada
#
# [10 rows x 26 columns]

# %%
print(df_presuntos.columns.tolist())

no_colombianos = df_presuntos[df_presuntos["País de Nacimiento"].str.strip().str.lower() != "colombia"]
print("Cantidad de registros NO colombianos:", len(no_colombianos))
# Out:
# ['Año del hecho', 'Ciclo Vital', 'Sexo de la victima', 'Estado Civil', 'País de Nacimiento', 'Escolaridad', 'Pertenencia Grupal', 'Pertenencia Étnica', 'Mes del hecho', 'Dia del hecho', 'Código Dane Municipio', 'Municipio del hecho DANE', 'Departamento del hecho DANE', 'Código Dane Departamento', 'Escenario del Hecho', 'Zona del Hecho', 'Circunstancia del Hecho Detallada', 'Manera de Muerte', 'Mecanismo Causal de la Lesión Fatal', 'Diagnostico Topográfico de la Lesión Fatal', 'Razón del Suicidio', 'Ancestro Racial', 'Pueblo Indígena', 'Orientación Sexual', 'Identidad de Género', 'Transgénero']
# Cantidad de registros NO colombianos: 0

# %%
df_presuntos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13819 entries, 1 to 14270
# Data columns (total 26 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Año del hecho                               13819 non-null  int64
#  1   Ciclo Vital                                 13819 non-null  object
#  2   Sexo de la victima                          13819 non-null  object
#  3   Estado Civil                                12481 non-null  object
#  4   País de Nacimiento                          13819 non-null  object
#  5   Escolaridad                                 12021 non-null  object
#  6   Pertenencia Grupal                          12281 non-null  object
#  7   Pertenencia Étnica                          12623 non-null  object
#  8   Mes del hecho                               13819 non-null  object
#  9   Dia del hecho                               13819 non-null  object
#  10  Código Dane Municipio                       13819 non-null  int64
#  11  Municipio del hecho DANE                    13816 non-null  object
#  12  Departamento del hecho DANE                 13816 non-null  object
#  13  Código Dane Departamento                    13819 non-null  int64
#  14  Escenario del Hecho                         13517 non-null  object
#  15  Zona del Hecho                              13732 non-null  object
#  16  Circunstancia del Hecho Detallada           13819 non-null  object
#  17  Manera de Muerte                            13819 non-null  object
#  18  Mecanismo Causal de la Lesión Fatal         13819 non-null  object
#  19  Diagnostico Topográfico de la Lesión Fatal  13819 non-null  object
#  20  Razón del Suicidio                          6596 non-null   object
#  21  Ancestro Racial                             13819 non-null  object
#  22  Pueblo Indígena                             13819 non-null  object
#  23  Orientación Sexual                          13819 non-null  object
#  24  Identidad de Género                         13819 non-null  object
#  25  Transgénero                                 13819 non-null  object
# dtypes: int64(3), object(23)
# memory usage: 2.8+ MB

# %% [markdown]
# ELIMINADERA DE COLUMNAS INNECESARIAS

# %%
df_presuntos=df_presuntos.drop("País de Nacimiento",axis = 1)

# %%
df_presuntos=df_presuntos.drop("Manera de Muerte",axis = 1)

# %%
df_presuntos=df_presuntos.drop("Código Dane Municipio",axis = 1)
df_presuntos=df_presuntos.drop("Código Dane Departamento",axis = 1)
df_presuntos=df_presuntos.drop("Pertenencia Grupal",axis = 1)
df_presuntos=df_presuntos.drop("Pertenencia Étnica",axis = 1)

# %%
df_presuntos.columns  #Muestra los nombres de Columna
# Out:
# Index(['Año del hecho', 'Ciclo Vital', 'Sexo de la victima', 'Estado Civil',
#        'Escolaridad', 'Mes del hecho', 'Dia del hecho',
#        'Municipio del hecho DANE', 'Departamento del hecho DANE',
#        'Escenario del Hecho', 'Zona del Hecho',
#        'Circunstancia del Hecho Detallada',
#        'Mecanismo Causal de la Lesión Fatal',
#        'Diagnostico Topográfico de la Lesión Fatal', 'Razón del Suicidio',
#        'Ancestro Racial', 'Pueblo Indígena', 'Orientación Sexual',
#        'Identidad de Género', 'Transgénero'],
#       dtype='object')

# %%
df_presuntos.drop(["Dia del hecho", "Zona del Hecho", "Ancestro Racial","Pueblo Indígena", "Orientación Sexual", "Transgénero"], axis=1, inplace=True)
#ELIMINO VARIAS COLUMNAS A LA VEZ.

# %%
df_presuntos=df_presuntos.drop("Circunstancia del Hecho Detallada",axis = 1)

# %%
df_presuntos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13819 entries, 1 to 14270
# Data columns (total 13 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Año del hecho                               13819 non-null  int64
#  1   Ciclo Vital                                 13819 non-null  object
#  2   Sexo de la victima                          13819 non-null  object
#  3   Estado Civil                                12481 non-null  object
#  4   Escolaridad                                 12021 non-null  object
#  5   Mes del hecho                               13819 non-null  object
#  6   Municipio del hecho DANE                    13816 non-null  object
#  7   Departamento del hecho DANE                 13816 non-null  object
#  8   Escenario del Hecho                         13517 non-null  object
#  9   Mecanismo Causal de la Lesión Fatal         13819 non-null  object
#  10  Diagnostico Topográfico de la Lesión Fatal  13819 non-null  object
#  11  Razón del Suicidio                          6596 non-null   object
#  12  Identidad de Género                         13819 non-null  object
# dtypes: int64(1), object(12)
# memory usage: 1.5+ MB

# %%
df_presuntos.head(10)
# Out:
#     Año del hecho               Ciclo Vital Sexo de la victima  \
# ID
# 1            2020         (29 a 59) Adultez              Mujer
# 2            2020        (18 a 28) Juventud             Hombre
# 3            2020        (18 a 28) Juventud             Hombre
# 4            2020        (18 a 28) Juventud             Hombre
# 5            2020        (18 a 28) Juventud             Hombre
# 6            2020         (29 a 59) Adultez             Hombre
# 7            2020         (29 a 59) Adultez             Hombre
# 8            2020    (12 a 17) Adolescencia              Mujer
# 9            2020         (29 a 59) Adultez             Hombre
# 10           2020  (Más de 60) Adulto Mayor             Hombre
#
#                   Estado Civil                                  Escolaridad  \
# ID
# 1                  Unión libre            Educación media o secundaria alta
# 2                   Soltero(a)  Educación técnica profesional y tecnológica
# 3                   Soltero(a)                    Educación básica primaria
# 4   Separado(a), divorciado(a)                                          NaN
# 5                   Soltero(a)            Educación media o secundaria alta
# 6                   Soltero(a)                    Educación básica primaria
# 7                   Soltero(a)            Educación media o secundaria alta
# 8                   Soltero(a)            Educación media o secundaria alta
# 9                  Unión libre            Educación media o secundaria alta
# 10                  Soltero(a)                    Educación básica primaria
#
#    Mes del hecho Municipio del hecho DANE Departamento del hecho DANE  \
# ID
# 1          enero             Bogotá, D.C.                Bogotá, D.C.
# 2          enero             Bogotá, D.C.                Bogotá, D.C.
# 3          enero             Bogotá, D.C.                Bogotá, D.C.
# 4          enero             Bogotá, D.C.                Bogotá, D.C.
# 5          enero             Bogotá, D.C.                Bogotá, D.C.
# 6          enero             Bogotá, D.C.                Bogotá, D.C.
# 7          enero             Bogotá, D.C.                Bogotá, D.C.
# 8          enero             Bogotá, D.C.                Bogotá, D.C.
# 9          enero             Bogotá, D.C.                Bogotá, D.C.
# 10         enero             Bogotá, D.C.                Bogotá, D.C.
#
#    Escenario del Hecho Mecanismo Causal de la Lesión Fatal  \
# ID
# 1             Vivienda              Generadores de asfixia
# 2             Vivienda                              Tóxico
# 3             Vivienda              Generadores de asfixia
# 4             Vivienda              Generadores de asfixia
# 5             Vivienda                              Tóxico
# 6             Vivienda              Generadores de asfixia
# 7             Vivienda          Proyectil de arma de fuego
# 8             Vivienda                              Tóxico
# 9             Vivienda              Generadores de asfixia
# 10            Vivienda              Generadores de asfixia
#
#    Diagnostico Topográfico de la Lesión Fatal  \
# ID
# 1                            Trauma de cuello
# 2                                Sin lesiones
# 3                            Trauma de cuello
# 4                            Trauma de cuello
# 5                                Sin lesiones
# 6                            Trauma de cuello
# 7                             Trauma de Tórax
# 8                                Sin lesiones
# 9                            Trauma de cuello
# 10                             Por determinar
#
#                   Razón del Suicidio         Identidad de Género
# ID
# 1   Conflicto con pareja o ex-pareja  No había sido implementada
# 2         Enfermedad física o mental  No había sido implementada
# 3         Enfermedad física o mental  No había sido implementada
# 4   Conflicto con pareja o ex-pareja  No había sido implementada
# 5         Enfermedad física o mental  No había sido implementada
# 6                                NaN  No había sido implementada
# 7   Conflicto con pareja o ex-pareja  No había sido implementada
# 8         Enfermedad física o mental  No había sido implementada
# 9   Conflicto con pareja o ex-pareja  No había sido implementada
# 10        Enfermedad física o mental  No había sido implementada

# %%
"""# Total de registros válidos (no nulos)
total = df_presuntos["Orientación Sexual"].notna().sum()

# Filtramos los que son diferentes a "no había sido implementada"
diferentes = df_presuntos[df_presuntos["Orientación Sexual"] != "No había sido implementada"].shape[0]

# Calculamos el porcentaje
porcentaje = (diferentes / total) * 100

print(f"Porcentaje de respuestas diferentes a 'No había sido implementada': {porcentaje:.2f}%")"""
# Out:
# '# Total de registros válidos (no nulos)\ntotal = df_presuntos["Orientación Sexual"].notna().sum()\n\n# Filtramos los que son diferentes a "no había sido implementada"\ndiferentes = df_presuntos[df_presuntos["Orientación Sexual"] != "No había sido implementada"].shape[0]\n\n# Calculamos el porcentaje\nporcentaje = (diferentes / total) * 100\n\nprint(f"Porcentaje de respuestas diferentes a \'No había sido implementada\': {porcentaje:.2f}%")'

# %%
"""df_presuntos["Orientación Sexual"] = df_presuntos["Orientación Sexual"].astype(str).str.strip().str.lower()
print(df_presuntos["Orientación Sexual"].unique())


df_presuntos["Identidad de Género"] = df_presuntos["Identidad de Género"].astype(str).str.strip().str.lower()
print(df_presuntos["Identidad de Género"].unique())"""
# Out:
# 'df_presuntos["Orientación Sexual"] = df_presuntos["Orientación Sexual"].astype(str).str.strip().str.lower()\nprint(df_presuntos["Orientación Sexual"].unique())\n\n\ndf_presuntos["Identidad de Género"] = df_presuntos["Identidad de Género"].astype(str).str.strip().str.lower()\nprint(df_presuntos["Identidad de Género"].unique())'

# %%
"""# Asegurarte de que sea texto y sin espacios extras
df_presuntos["Orientación Sexual"] = df_presuntos["Orientación Sexual"].astype(str).str.strip().str.lower()

# Total de respuestas válidas (no vacías)
total = df_presuntos["Orientación Sexual"].notna().sum()

# Cantidad de respuestas iguales a "no había sido implementada"
cantidad = (df_presuntos["Orientación Sexual"] == "no había sido implementada").sum()

# Porcentaje
porcentaje = (cantidad / total) * 100

print(f"Total de respuestas válidas: {total}")
print(f"Cantidad de 'No había sido implementada': {cantidad}")
print(f"Porcentaje: {porcentaje:.2f}%")"""
# Out:
# '# Asegurarte de que sea texto y sin espacios extras\ndf_presuntos["Orientación Sexual"] = df_presuntos["Orientación Sexual"].astype(str).str.strip().str.lower()\n\n# Total de respuestas válidas (no vacías)\ntotal = df_presuntos["Orientación Sexual"].notna().sum()\n\n# Cantidad de respuestas iguales a "no había sido implementada"\ncantidad = (df_presuntos["Orientación Sexual"] == "no había sido implementada").sum()\n\n# Porcentaje\nporcentaje = (cantidad / total) * 100\n\nprint(f"Total de respuestas válidas: {total}")\nprint(f"Cantidad de \'No había sido implementada\': {cantidad}")\nprint(f"Porcentaje: {porcentaje:.2f}%")'

# %%
df_presuntos["Razón del Suicidio"] = df_presuntos["Razón del Suicidio"].astype(str).str.strip().str.lower()
print(df_presuntos["Razón del Suicidio"].unique())
# Out:
# ['conflicto con pareja o ex-pareja' 'enfermedad física o mental' 'nan'
#  'muerte de un familiar o amigo' 'desamor' 'económicas'
#  'maltrato físico - sexual - psicológico' 'otras'
#  'abuso de sustancia y alcohol' 'escolares - educativas' 'laborales'
#  'orientación sexual diversa' 'suicidio de un familiar o amigo' 'bullying'
#  'jurídicas' 'accesos a armas de fuego' 'víctima de hostigamiento'
#  'estado de gestación' 'enfermedad mental' 'abuso de sustancias y alcohol'
#  'enfermedad física' 'acceso a armas de fuego'
#  'maltrato fisico - sexual - psicologico'
#  'conflicto con pareja o ex pareja' 'escolares / educativas'
#  'contacto sexual engañoso' 'ciberacoso'
#  'adiccion a los juegos de apuestas o azar'
#  'adicción a los juegos de apuestas o azar']

# %%
print(df_presuntos["Razón del Suicidio"].value_counts(dropna=False))
# Out:
# Razón del Suicidio
# nan                                         7223
# enfermedad mental                           1756
# desamor                                      914
# económicas                                   813
# conflicto con pareja o ex-pareja             693
# conflicto con pareja o ex pareja             541
# enfermedad física                            422
# enfermedad física o mental                   388
# abuso de sustancias y alcohol                387
# muerte de un familiar o amigo                244
# jurídicas                                     68
# otras                                         44
# maltrato físico - sexual - psicológico        44
# laborales                                     41
# abuso de sustancia y alcohol                  37
# escolares / educativas                        31
# bullying                                      31
# escolares - educativas                        27
# orientación sexual diversa                    26
# suicidio de un familiar o amigo               24
# acceso a armas de fuego                       22
# víctima de hostigamiento                      17
# maltrato fisico - sexual - psicologico         9
# ciberacoso                                     5
# estado de gestación                            4
# adiccion a los juegos de apuestas o azar       3
# accesos a armas de fuego                       2
# adicción a los juegos de apuestas o azar       2
# contacto sexual engañoso                       1
# Name: count, dtype: int64

# %%
df_presuntos.tail(5) #Con .tail(10) muestras las ultimas 10 filas del df
# Out:
#        Año del hecho         Ciclo Vital Sexo de la victima Estado Civil  \
# ID
# 14266           2024  (18 a 28) Juventud             Hombre          NaN
# 14267           2024   (29 a 59) Adultez             Hombre  Unión libre
# 14268           2024  (18 a 28) Juventud              Mujer  Unión libre
# 14269           2024  (18 a 28) Juventud              Mujer   Soltero(a)
# 14270           2024   (29 a 59) Adultez             Hombre  Unión libre
#
#                              Escolaridad Mes del hecho  \
# ID
# 14266                                NaN     Noviembre
# 14267          Educación básica primaria     Noviembre
# 14268  Educación media o secundaria alta     Diciembre
# 14269          Educación básica primaria     Diciembre
# 14270          Educación básica primaria     Noviembre
#
#       Municipio del hecho DANE Departamento del hecho DANE  \
# ID
# 14266                    Tuluá             Valle del Cauca
# 14267                San Pedro             Valle del Cauca
# 14268                    Tuluá             Valle del Cauca
# 14269                    Tuluá             Valle del Cauca
# 14270              Bucaramanga                   Santander
#
#       Escenario del Hecho Mecanismo Causal de la Lesión Fatal  \
# ID
# 14266            Vivienda                              Tóxico
# 14267            Vivienda              Generadores de asfixia
# 14268            Vivienda          Proyectil de arma de fuego
# 14269            Vivienda              Generadores de asfixia
# 14270                 NaN                              Tóxico
#
#       Diagnostico Topográfico de la Lesión Fatal Razón del Suicidio  \
# ID
# 14266                               Sin lesiones                nan
# 14267                           Trauma de cuello                nan
# 14268                            Trauma craneano            desamor
# 14269                           Trauma de cuello                nan
# 14270                               Sin lesiones                nan
#
#         Identidad de Género
# ID
# 14266  No Sabe / No Informa
# 14267  No Sabe / No Informa
# 14268              Femenino
# 14269              Femenino
# 14270             Masculino

# %%
df_presuntos.columns  #Muestra los nombres de Columna
# Out:
# Index(['Año del hecho', 'Ciclo Vital', 'Sexo de la victima', 'Estado Civil',
#        'Escolaridad', 'Mes del hecho', 'Municipio del hecho DANE',
#        'Departamento del hecho DANE', 'Escenario del Hecho',
#        'Mecanismo Causal de la Lesión Fatal',
#        'Diagnostico Topográfico de la Lesión Fatal', 'Razón del Suicidio',
#        'Identidad de Género'],
#       dtype='object')

# %%
df_presuntos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13819 entries, 1 to 14270
# Data columns (total 13 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Año del hecho                               13819 non-null  int64
#  1   Ciclo Vital                                 13819 non-null  object
#  2   Sexo de la victima                          13819 non-null  object
#  3   Estado Civil                                12481 non-null  object
#  4   Escolaridad                                 12021 non-null  object
#  5   Mes del hecho                               13819 non-null  object
#  6   Municipio del hecho DANE                    13816 non-null  object
#  7   Departamento del hecho DANE                 13816 non-null  object
#  8   Escenario del Hecho                         13517 non-null  object
#  9   Mecanismo Causal de la Lesión Fatal         13819 non-null  object
#  10  Diagnostico Topográfico de la Lesión Fatal  13819 non-null  object
#  11  Razón del Suicidio                          13819 non-null  object
#  12  Identidad de Género                         13819 non-null  object
# dtypes: int64(1), object(12)
# memory usage: 1.5+ MB

# %%
df_presuntos.isna().sum()
# Out:
# Año del hecho                                    0
# Ciclo Vital                                      0
# Sexo de la victima                               0
# Estado Civil                                  1338
# Escolaridad                                   1798
# Mes del hecho                                    0
# Municipio del hecho DANE                         3
# Departamento del hecho DANE                      3
# Escenario del Hecho                            302
# Mecanismo Causal de la Lesión Fatal              0
# Diagnostico Topográfico de la Lesión Fatal       0
# Razón del Suicidio                               0
# Identidad de Género                              0
# dtype: int64

# %%
df_presuntos.reset_index(drop=True, inplace=True) #Para que el índice refleje exactamente las 13.819 filas
df_presuntos.index += 1  # para que empiece en 1, no en 0

# %%
# 2️⃣ Exportar el DataFrame a CSV (codificación UTF-8)
df_presuntos.to_csv(
    r"E:\TalentoTech_Analista_de_Datos\Df_Exportados\df_presuntos_limpio_V1.csv",
    index=False,          # No incluir el índice en el archivo
    encoding='utf-8'      # Guardar con codificación UTF-8
)

# 3️⃣ Exportar el DataFrame a Excel
df_presuntos.to_excel(
    r"E:\TalentoTech_Analista_de_Datos\Df_Exportados\df_presuntos_limpio_V1.xlsx",
    index=False,          # No incluir el índice
    sheet_name='Presuntos_Suicidios'  # Nombre de la hoja en Excel
)
